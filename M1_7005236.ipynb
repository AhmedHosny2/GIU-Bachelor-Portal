# %% [markdown]
# <a href="https://colab.research.google.com/github/AhmedOsamaAli/GIU-bachelor-Portal/blob/master/M1_7005236.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib as plt
import pandas as pd
import seaborn as sb

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-5750e3cb-0a02-49fa-a147-63391c4673aa" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5750e3cb-0a02-49fa-a147-63391c4673aa">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
df2 = pd.read_csv(io.BytesIO(uploaded['imdb_top_1000.csv']))
# Dataset is now stored in a Pandas Dataframe

# %%
df2.head(10)
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
# 5  https://m.media-amazon.com/images/M/MV5BNzA5ZD...
# 6  https://m.media-amazon.com/images/M/MV5BNGNhMD...
# 7  https://m.media-amazon.com/images/M/MV5BNDE4OT...
# 8  https://m.media-amazon.com/images/M/MV5BMjAxMz...
# 9  https://m.media-amazon.com/images/M/MV5BMmEzNT...
#
#                                     Series_Title Released_Year Certificate  \
# 0                       The Shawshank Redemption          1994           A
# 1                                  The Godfather          1972           A
# 2                                The Dark Knight          2008          UA
# 3                         The Godfather: Part II          1974           A
# ...

# %%
df2.tail(10)
# Out:
#                                            Poster_Link  \
# 990  https://m.media-amazon.com/images/M/MV5BYjRmY2...
# 991  https://m.media-amazon.com/images/M/MV5BMzAyND...
# 992  https://m.media-amazon.com/images/M/MV5BMjAwMT...
# 993  https://m.media-amazon.com/images/M/MV5BYTE4YW...
# 994  https://m.media-amazon.com/images/M/MV5BZjQyMG...
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 990            Giù la testa          1971          PG  157 min
# 991          Kelly's Heroes          1970          GP  144 min
# 992         The Jungle Book          1967           U   78 min
# 993                  Blowup          1966           A  111 min
# ...

# %%
rows = len(df2.axes[0])
# computing number of columns
cols = len(df2.axes[1])
print("Number of Rows: ", rows)
print("Number of Columns: ", cols)
# Out:
# Number of Rows:  1000
# Number of Columns:  16

# %%
# Get the list of all column names from headers
column_headers = list(df2.columns.values)
print("The Column Header :", column_headers)
# Out:
# The Column Header : ['Poster_Link', 'Series_Title', 'Released_Year', 'Certificate', 'Runtime', 'Genre', 'IMDB_Rating', 'Overview', 'Meta_score', 'Director', 'Star1', 'Star2', 'Star3', 'Star4', 'No_of_Votes', 'Gross']

# %%
# Select last column of dataframe as a series
print(list(df2.columns)[-1])
# Out:
# Gross

# %%
print(type(list(df2.columns)[3]))
# Out:
# <class 'str'>

# %%
def Solve(dd):
  SS =set()
  for i in dd :
    SS.add(i)
  print(len(SS))
Solve(df2['Meta_score'])
# Out:
# 220

# %%
print(df2['Meta_score'].mode()[0])
# Out:
# 76.0

# %%
nums = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
df = df2.select_dtypes(include=nums)
print(df2.describe())
# Out:
#        IMDB_Rating  Meta_score   No_of_Votes
# count  1000.000000  843.000000  1.000000e+03
# mean      7.949300   77.971530  2.736929e+05
# std       0.275491   12.376099  3.273727e+05
# min       7.600000   28.000000  2.508800e+04
# 25%       7.700000   70.000000  5.552625e+04
# 50%       7.900000   79.000000  1.385485e+05
# 75%       8.100000   87.000000  3.741612e+05
# max       9.300000  100.000000  2.343110e+06

# %%
print(df2[df2["Certificate"] == 'A' ])
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 6    https://m.media-amazon.com/images/M/MV5BNGNhMD...
# 7    https://m.media-amazon.com/images/M/MV5BNDE4OT...
# ..                                                 ...
# 985  https://m.media-amazon.com/images/M/MV5BNDQ3Mz...
# 987  https://m.media-amazon.com/images/M/MV5BNDU1Mj...
# 989  https://m.media-amazon.com/images/M/MV5BYzZhOD...
# 993  https://m.media-amazon.com/images/M/MV5BYTE4YW...
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
#
#                  Series_Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A  142 min
# 1               The Godfather          1972           A  175 min
# 3      The Godfather: Part II          1974           A  202 min
# ...

# %%
print(df2['Meta_score'].describe())
# Out:
# count    843.000000
# mean      77.971530
# std       12.376099
# min       28.000000
# 25%       70.000000
# 50%       79.000000
# 75%       87.000000
# max      100.000000
# Name: Meta_score, dtype: float64

# %%
df2["Meta_score"].astype(object)
# Out:
# 0       80.0
# 1      100.0
# 2       84.0
# 3       90.0
# 4       96.0
#        ...
# 995     76.0
# 996     84.0
# 997     85.0
# 998     78.0
# 999     93.0
# Name: Meta_score, Length: 1000, dtype: object

# %%
df2.groupby(['Meta_score','Genre']).sum()
# Out:
#                                        IMDB_Rating  No_of_Votes
# Meta_score Genre
# 28.0       Drama                               7.7       142863
# 30.0       Drama, Sci-Fi, Thriller             7.6       451479
# 33.0       Action, Crime, Drama                8.0        98097
# 36.0       Drama                               7.6       286770
# 40.0       Drama, Sport                        7.7        32628
# ...                                            ...          ...
# 100.0      Drama, Mystery                      8.3       403351
#            Drama, Mystery, Romance             8.1        90729
#            Drama, Romance, War                 8.5       522093
#            Mystery, Romance, Thriller          8.3       364368
#            Mystery, Thriller                   8.4       444074
#
# [725 rows x 2 columns]

# %%
df2.isnull().sum()
# Out:
# Poster_Link        0
# Series_Title       0
# Released_Year      0
# Certificate      101
# Runtime            0
# Genre              0
# IMDB_Rating        0
# Overview           0
# Meta_score       157
# Director           0
# Star1              0
# Star2              0
# Star3              0
# Star4              0
# No_of_Votes        0
# Gross            169
# dtype: int64

# %%
df2['Certificate'] = df2['Certificate'].fillna(df2['Certificate'].mode()[0])

# %%
df2['Meta_score'] = df2['Meta_score'].fillna(df2['Meta_score'].mode()[0])
df2['Gross'] = df2['Gross'].fillna(df2['Gross'].mode()[0])

# %%
df2.duplicated().sum()
df2.drop_duplicates()
df2.duplicated().sum()
# Out:
# 0

# %%
df2.groupby(pd.cut(df2['Meta_score'],bins = 6)).count()
# Out:
#                 Poster_Link  Series_Title  Released_Year  Certificate  \
# Meta_score
# (27.928, 40.0]            5             5              5            5
# (40.0, 52.0]             26            26             26           26
# (52.0, 64.0]             81            81             81           81
# (64.0, 76.0]            406           406            406          406
# (76.0, 88.0]            305           305            305          305
# (88.0, 100.0]           177           177            177          177
#
#                 Runtime  Genre  IMDB_Rating  Overview  Meta_score  Director  \
# Meta_score
# (27.928, 40.0]        5      5            5         5           5         5
# (40.0, 52.0]         26     26           26        26          26        26
# (52.0, 64.0]         81     81           81        81          81        81
# (64.0, 76.0]        406    406          406       406         406       406
# ...

# %%
df2[df2.Meta_score == df2.Meta_score.max()]
# Out:
#                                            Poster_Link  \
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 50   https://m.media-amazon.com/images/M/MV5BY2IzZG...
# 81   https://m.media-amazon.com/images/M/MV5BNGUxYW...
# 116  https://m.media-amazon.com/images/M/MV5BYWY5Zj...
# 119  https://m.media-amazon.com/images/M/MV5BYTE4OD...
# 124  https://m.media-amazon.com/images/M/MV5BYjBiOT...
# 260  https://m.media-amazon.com/images/M/MV5BYTg1Mm...
# 274  https://m.media-amazon.com/images/M/MV5BZmQzMD...
# 423  https://m.media-amazon.com/images/M/MV5BODFlYz...
# 440  https://m.media-amazon.com/images/M/MV5BMjE5NT...
# 491  https://m.media-amazon.com/images/M/MV5BMTYzND...
# 559  https://m.media-amazon.com/images/M/MV5BYTc1NG...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 1             The Godfather          1972           A  175 min
# 50               Casablanca          1942           U  102 min
# ...

# %%
sb.boxplot(df2.IMDB_Rating)
# Out:
# <Axes: >

# %%
sb.histplot(df2.IMDB_Rating)
# Out:
# <Axes: xlabel='IMDB_Rating', ylabel='Count'>

# %%
sb.scatterplot(x =df2.IMDB_Rating , y =df2.Meta_score)
# Out:
# <Axes: xlabel='IMDB_Rating', ylabel='Meta_score'>
